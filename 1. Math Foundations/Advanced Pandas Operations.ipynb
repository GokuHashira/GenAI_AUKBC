# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Exercise 1: Load and examine a superstore sales data from an Excel file

# %%
df = pd.read_excel("Sample - Superstore.xls")

# %%
df.head(10)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 7  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 8  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 9  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
# 5       90032    West  FUR-FU-10001487        Furniture  Furnishings
# 6       90032    West  OFF-AR-10002833  Office Supplies          Art
# 7       90032    West  TEC-PH-10002275       Technology       Phones
# 8       90032    West  OFF-BI-10003910  Office Supplies      Binders
# 9       90032    West  OFF-AP-10002892  Office Supplies   Appliances
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.8600         7
# 6                                         Newell 322    7.2800         4
# 7                     Mitel 5320 IP Phone VoIP phone  907.1520         6
# 8  DXL Angle-View Binders with Locking Rings by S...   18.5040         3
# 9                   Belkin F5C206VTEL 6 Outlet Surge  114.9000         5
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
# 5      0.00   14.1694
# 6      0.00    1.9656
# 7      0.20   90.7152
# 8      0.20    5.7825
# 9      0.00   34.4700
#
# [10 rows x 21 columns]

# %%
df.drop('Row ID',axis=1,inplace=True)

# %%
df.shape
# Out:
# (9994, 20)

# %% [markdown]
# ### Exercise 2: Subsetting the DataFrame

# %%
df_subset = df.loc[[i for i in range(5,10)],['Customer ID','Customer Name','City','Postal Code','Sales']]
df_subset
# Out:
#   Customer ID    Customer Name         City  Postal Code    Sales
# 5    BH-11710  Brosina Hoffman  Los Angeles        90032   48.860
# 6    BH-11710  Brosina Hoffman  Los Angeles        90032    7.280
# 7    BH-11710  Brosina Hoffman  Los Angeles        90032  907.152
# 8    BH-11710  Brosina Hoffman  Los Angeles        90032   18.504
# 9    BH-11710  Brosina Hoffman  Los Angeles        90032  114.900

# %% [markdown]
# ### Exercise 3: An example use case – determining statistics on sales and profit for records 100-199

# %%
df_subset = df.loc[[i for i in range(100,200)],['Sales','Profit']]

# %%
df_subset.describe()
# Out:
#              Sales       Profit
# count   100.000000   100.000000
# mean    262.957220     0.347574
# std     858.983762   170.744869
# min       1.788000 -1359.992000
# 25%      21.327000     1.635900
# 50%      66.960000     9.653600
# 75%     177.095000    23.458800
# max    8159.952000   585.552000

# %%
df_subset.plot.box()
plt.title("Boxplot of sales and profit",fontsize=15)
plt.ylim(0,500)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercise 4: A useful function – unique

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
df['State'].nunique()
# Out:
# 49

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df.drop('Country',axis=1,inplace=True)

# %% [markdown]
# ### Exercise 5: Conditional Selection and Boolean Filtering

# %%
df_subset = df.loc[[i for i in range (10)],['Ship Mode','State','Sales']]
df_subset
# Out:
#         Ship Mode       State     Sales
# 0    Second Class    Kentucky  261.9600
# 1    Second Class    Kentucky  731.9400
# 2    Second Class  California   14.6200
# 3  Standard Class     Florida  957.5775
# 4  Standard Class     Florida   22.3680
# 5  Standard Class  California   48.8600
# 6  Standard Class  California    7.2800
# 7  Standard Class  California  907.1520
# 8  Standard Class  California   18.5040
# 9  Standard Class  California  114.9000

# %%
df_subset.Sales>100
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9     True
# Name: Sales, dtype: bool

# %%
df_subset[df_subset['Sales']>100]
# Out:
#         Ship Mode       State     Sales
# 0    Second Class    Kentucky  261.9600
# 1    Second Class    Kentucky  731.9400
# 3  Standard Class     Florida  957.5775
# 7  Standard Class  California  907.1520
# 9  Standard Class  California  114.9000

# %%
df_subset[(df_subset['State']!='California') & (df_subset['Sales']>100)]
# Out:
#         Ship Mode     State     Sales
# 0    Second Class  Kentucky  261.9600
# 1    Second Class  Kentucky  731.9400
# 3  Standard Class   Florida  957.5775

# %% [markdown]
# ### Exercise 6: Setting and re-setting index

# %%
matrix_data = np.matrix('22,66,140;42,70,148;30,62,125;35,68,160;25,62,152')
row_labels = ['A','B','C','D','E']
column_headings = ['Age', 'Height', 'Weight']

df1 = pd.DataFrame(data=matrix_data, index=row_labels, columns=column_headings)
print("\nThe DataFrame\n",'-'*25, sep='')
print(df1)
print("\nAfter resetting index\n",'-'*35, sep='')
print(df1.reset_index())
print("\nAfter resetting index with 'drop' option TRUE\n",'-'*45, sep='')
print(df1.reset_index(drop=True))
print("\nAdding a new column 'Profession'\n",'-'*45, sep='')
df1['Profession'] = "Student Teacher Engineer Doctor Nurse".split()
print(df1)
print("\nSetting 'Profession' column as index\n",'-'*45, sep='')
print (df1.set_index('Profession'))
# Out:
# The DataFrame
# -------------------------
#    Age  Height  Weight
# A   22      66     140
# B   42      70     148
# C   30      62     125
# D   35      68     160
# E   25      62     152
#
# After resetting index
# -----------------------------------
#   index  Age  Height  Weight
# 0     A   22      66     140
# 1     B   42      70     148
# 2     C   30      62     125
# 3     D   35      68     160
# 4     E   25      62     152
#
# After resetting index with 'drop' option TRUE
# ---------------------------------------------
#    Age  Height  Weight
# 0   22      66     140
# 1   42      70     148
# 2   30      62     125
# 3   35      68     160
# 4   25      62     152
#
# Adding a new column 'Profession'
# ---------------------------------------------
#    Age  Height  Weight Profession
# A   22      66     140    Student
# B   42      70     148    Teacher
# C   30      62     125   Engineer
# D   35      68     160     Doctor
# E   25      62     152      Nurse
#
# Setting 'Profession' column as index
# ---------------------------------------------
#             Age  Height  Weight
# Profession
# Student      22      66     140
# Teacher      42      70     148
# Engineer     30      62     125
# Doctor       35      68     160
# Nurse        25      62     152

# %% [markdown]
# ### Exercise 7: GroupBy method

# %%
df_subset = df.loc[[i for i in range (10)],['Ship Mode','State','Sales']]
df_subset
# Out:
#         Ship Mode       State     Sales
# 0    Second Class    Kentucky  261.9600
# 1    Second Class    Kentucky  731.9400
# 2    Second Class  California   14.6200
# 3  Standard Class     Florida  957.5775
# 4  Standard Class     Florida   22.3680
# 5  Standard Class  California   48.8600
# 6  Standard Class  California    7.2800
# 7  Standard Class  California  907.1520
# 8  Standard Class  California   18.5040
# 9  Standard Class  California  114.9000

# %%
df_subset = df.loc[[i for i in range (10)],['State','Sales']]
df_subset
# Out:
#         State     Sales
# 0    Kentucky  261.9600
# 1    Kentucky  731.9400
# 2  California   14.6200
# 3     Florida  957.5775
# 4     Florida   22.3680
# 5  California   48.8600
# 6  California    7.2800
# 7  California  907.1520
# 8  California   18.5040
# 9  California  114.9000

# %%
# This is erroring out!
df_subset.groupby(['State']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)   6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)  12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'Second ClassStandard ClassStandard ClassStandard ClassStandard ClassStandard Class' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df_subset.groupby(['State']).mean()
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/internals/blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File ~/Desktop/Gk_Work/personal/GenAI_AUKBC/venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
byState = df_subset.groupby(['State'])

# %%
df_subset.groupby(['State']).mean()
# Out:
#                  Sales
# State
# California  185.219333
# Florida     489.972750
# Kentucky    496.950000

# %%
type(byState)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
print("\nGrouping by 'State' column and listing mean sales\n",'-'*50, sep='')
#print(byState.agg('mean'))
byState.mean()
# Out:
# Grouping by 'State' column and listing mean sales
# --------------------------------------------------
#                  Sales
# State
# California  185.219333
# Florida     489.972750
# Kentucky    496.950000

# %% [markdown]
# The groupby method is not working with Ship Mode, Sales and State together. It is working induvidually.

# %%
print("\nGrouping by 'State' column and listing total sum of sales\n",'-'*50, sep='')
print(byState.sum())
# Out:
# Grouping by 'State' column and listing total sum of sales
# --------------------------------------------------
#                 Sales
# State
# California  1111.3160
# Florida      979.9455
# Kentucky     993.9000

# %%
print(pd.DataFrame(df_subset.groupby('State').describe().loc['California']).transpose())
# Out:
#            Sales
#            count        mean         std   min     25%     50%    75%      max
# California   6.0  185.219333  355.889307  7.28  15.591  33.682  98.39  907.152

# %%
df_subset.groupby('Ship Mode').describe().loc[['Second Class','Standard Class']]
# Out:
#                Sales                                                           \
#                count        mean         std    min      25%     50%      75%
# Ship Mode
# Second Class     3.0  336.173333  364.373037  14.62  138.290  261.96  496.950
# Standard Class   7.0  296.663071  435.947552   7.28   20.436   48.86  511.026
#
#
#                      max
# Ship Mode
# Second Class    731.9400
# Standard Class  957.5775

# %%
pd.DataFrame(byState.describe().loc['California'])
# Out:
#              California
# Sales count    6.000000
#       mean   185.219333
#       std    355.889307
#       min      7.280000
#       25%     15.591000
#       50%     33.682000
#       75%     98.390000
#       max    907.152000

# %%
byStateCity=df.groupby(['State','City'])

# %%
byStateCity.describe()['Sales']
# Out:
#                       count         mean       min        25%       50%  \
# State     City
# Alabama   Auburn        6.0   294.471667     3.760     8.8050   182.030
#           Decatur      13.0   259.601538    14.940    23.9200    44.950
#           Florence      5.0   399.470000     4.980     7.2700    12.480
#           Hoover        4.0   131.462500     7.160    13.3925    20.725
#           Huntsville   10.0   248.437000     3.620    26.8700    81.920
# ...                     ...          ...       ...        ...       ...
# Wisconsin Superior      9.0   144.414444     5.560    17.1200    47.400
#           Waukesha      1.0    54.500000    54.500    54.5000    54.500
#           Wausau        4.0    79.370000    12.390    20.0325    29.605
#           West Allis    2.0   125.240000     8.520    66.8800   125.240
# Wyoming   Cheyenne      1.0  1603.136000  1603.136  1603.1360  1603.136
#
#                             75%       max         std
# State     City
# Alabama   Auburn       456.4075   900.080  361.914543
#           Decatur      239.9200  1215.920  385.660903
#           Florence     152.7600  1819.860  796.488863
#           Hoover       138.7950   477.240  230.646923
#           Huntsville   171.8075  1319.960  419.576667
# ...                         ...       ...         ...
# Wisconsin Superior     125.9900   629.100  213.394065
#           Waukesha      54.5000    54.500         NaN
#           Wausau        88.9425   245.880  111.450605
#           West Allis   183.6000   241.960  165.067007
# Wyoming   Cheyenne    1603.1360  1603.136         NaN
#
# [604 rows x 8 columns]

# %% [markdown]
# ### Exercise 8: Missing values in Pandas

# %%
df_missing=pd.read_excel("Sample - Superstore.xls",sheet_name="Missing")

# %%
df_missing
# Out:
#               Customer      Product     Sales  Quantity  Discount   Profit
# 0      Brosina Hoffman          NaN  1706.184       9.0       0.2  85.3092
# 1      Brosina Hoffman       Phones   911.424       4.0       0.2  68.3568
# 2   Zuschuss Donatelli          Art     8.560       2.0       0.0   2.4824
# 3   Zuschuss Donatelli       Phones       NaN       3.0       0.2  16.0110
# 4   Zuschuss Donatelli      Binders    22.720       4.0       0.2   7.3840
# 5        Eric Hoffmann      Binders    11.648       NaN       0.2   4.2224
# 6        Eric Hoffmann  Accessories    90.570       3.0       0.0  11.7741
# 7         Ruben Ausman          NaN    77.880       2.0       0.0      NaN
# 8                  NaN  Accessories    13.980       2.0       0.0   6.1512
# 9         Kunst Miller      Binders    25.824       6.0       0.2   9.3612
# 10        Kunst Miller        Paper   146.730       3.0       0.0  68.9631

# %%
df_missing.isnull()
# Out:
#     Customer  Product  Sales  Quantity  Discount  Profit
# 0      False     True  False     False     False   False
# 1      False    False  False     False     False   False
# 2      False    False  False     False     False   False
# 3      False    False   True     False     False   False
# 4      False    False  False     False     False   False
# 5      False    False  False      True     False   False
# 6      False    False  False     False     False   False
# 7      False     True  False     False     False    True
# 8       True    False  False     False     False   False
# 9      False    False  False     False     False   False
# 10     False    False  False     False     False   False

# %%
for c in df_missing.columns:
    miss = df_missing[c].isnull().sum()
    if miss>0:
        print("{} has {} missing value(s)".format(c,miss))
    else:
        print("{} has NO missing value!".format(c))
# Out:
# Customer has 1 missing value(s)
# Product has 2 missing value(s)
# Sales has 1 missing value(s)
# Quantity has 1 missing value(s)
# Discount has NO missing value!
# Profit has 1 missing value(s)

# %% [markdown]
# ### Exercise 9: Filling missing values with `fillna()`

# %%
df_missing.fillna('FILL')
# Out:
#               Customer      Product     Sales Quantity  Discount   Profit
# 0      Brosina Hoffman         FILL  1706.184      9.0       0.2  85.3092
# 1      Brosina Hoffman       Phones   911.424      4.0       0.2  68.3568
# 2   Zuschuss Donatelli          Art      8.56      2.0       0.0   2.4824
# 3   Zuschuss Donatelli       Phones      FILL      3.0       0.2   16.011
# 4   Zuschuss Donatelli      Binders     22.72      4.0       0.2    7.384
# 5        Eric Hoffmann      Binders    11.648     FILL       0.2   4.2224
# 6        Eric Hoffmann  Accessories     90.57      3.0       0.0  11.7741
# 7         Ruben Ausman         FILL     77.88      2.0       0.0     FILL
# 8                 FILL  Accessories     13.98      2.0       0.0   6.1512
# 9         Kunst Miller      Binders    25.824      6.0       0.2   9.3612
# 10        Kunst Miller        Paper    146.73      3.0       0.0  68.9631

# %%
df_missing[['Customer','Product']].fillna('FILL')
# Out:
#               Customer      Product
# 0      Brosina Hoffman         FILL
# 1      Brosina Hoffman       Phones
# 2   Zuschuss Donatelli          Art
# 3   Zuschuss Donatelli       Phones
# 4   Zuschuss Donatelli      Binders
# 5        Eric Hoffmann      Binders
# 6        Eric Hoffmann  Accessories
# 7         Ruben Ausman         FILL
# 8                 FILL  Accessories
# 9         Kunst Miller      Binders
# 10        Kunst Miller        Paper

# %%
df_missing['Sales'].fillna(method='ffill')
# Out:
# /tmp/ipykernel_9993/1584454419.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_missing['Sales'].fillna(method='ffill')
# 0     1706.184
# 1      911.424
# 2        8.560
# 3        8.560
# 4       22.720
# 5       11.648
# 6       90.570
# 7       77.880
# 8       13.980
# 9       25.824
# 10     146.730
# Name: Sales, dtype: float64

# %%
df_missing['Sales'].fillna(method='bfill')
# Out:
# /tmp/ipykernel_9993/1648446437.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_missing['Sales'].fillna(method='bfill')
# 0     1706.184
# 1      911.424
# 2        8.560
# 3       22.720
# 4       22.720
# 5       11.648
# 6       90.570
# 7       77.880
# 8       13.980
# 9       25.824
# 10     146.730
# Name: Sales, dtype: float64

# %%
#df_missing.mean()
df_missing['Sales'].mean()
# Out:
# np.float64(301.552)

# %%
df_missing['Sales'].fillna(df_missing['Sales'].mean())
# Out:
# 0     1706.184
# 1      911.424
# 2        8.560
# 3      301.552
# 4       22.720
# 5       11.648
# 6       90.570
# 7       77.880
# 8       13.980
# 9       25.824
# 10     146.730
# Name: Sales, dtype: float64

# %% [markdown]
# ### Exercise 10: Dropping missing values with `dropna()`

# %%
df_missing.dropna(axis=0)
# Out:
#               Customer      Product    Sales  Quantity  Discount   Profit
# 1      Brosina Hoffman       Phones  911.424       4.0       0.2  68.3568
# 2   Zuschuss Donatelli          Art    8.560       2.0       0.0   2.4824
# 4   Zuschuss Donatelli      Binders   22.720       4.0       0.2   7.3840
# 6        Eric Hoffmann  Accessories   90.570       3.0       0.0  11.7741
# 9         Kunst Miller      Binders   25.824       6.0       0.2   9.3612
# 10        Kunst Miller        Paper  146.730       3.0       0.0  68.9631

# %%
df_missing.dropna(axis=1)
# Out:
#     Discount
# 0        0.2
# 1        0.2
# 2        0.0
# 3        0.2
# 4        0.2
# 5        0.2
# 6        0.0
# 7        0.0
# 8        0.0
# 9        0.2
# 10       0.0

# %%
df_missing.dropna(axis=1,thresh=10)
# Out:
#               Customer     Sales  Quantity  Discount   Profit
# 0      Brosina Hoffman  1706.184       9.0       0.2  85.3092
# 1      Brosina Hoffman   911.424       4.0       0.2  68.3568
# 2   Zuschuss Donatelli     8.560       2.0       0.0   2.4824
# 3   Zuschuss Donatelli       NaN       3.0       0.2  16.0110
# 4   Zuschuss Donatelli    22.720       4.0       0.2   7.3840
# 5        Eric Hoffmann    11.648       NaN       0.2   4.2224
# 6        Eric Hoffmann    90.570       3.0       0.0  11.7741
# 7         Ruben Ausman    77.880       2.0       0.0      NaN
# 8                  NaN    13.980       2.0       0.0   6.1512
# 9         Kunst Miller    25.824       6.0       0.2   9.3612
# 10        Kunst Miller   146.730       3.0       0.0  68.9631

# %% [markdown]
# ### Exercise 11: Outlier detection using simple statistical test

# %%
df_sample = df[['Customer Name','State','Sales','Profit']].sample(n=50).copy()

# %%
# Assign a wrong (negative value) in few places
df_sample['Sales'].iloc[5]=-1000.0
df_sample['Sales'].iloc[15]=-500.0
# Out:
# /tmp/ipykernel_9993/2735798822.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_sample['Sales'].iloc[5]=-1000.0
# /tmp/ipykernel_9993/2735798822.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sample['Sales'].iloc[5]=-1000.0
# /tmp/ipykernel_9993/2735798822.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_sample['Sales'].iloc[15]=-500.0
# /tmp/ipykernel_9993/2735798822.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sample['Sales'].iloc[15]=-500.0

# %%
df_sample.plot.box()
plt.title("Boxplot of sales and profit", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True)

# %% [markdown]
# ### Exercise 12: Concatenation

# %%
df_1 = df[['Customer Name','State','Sales','Profit']].sample(n=4)
df_2 = df[['Customer Name','State','Sales','Profit']].sample(n=4)
df_3 = df[['Customer Name','State','Sales','Profit']].sample(n=4)

# %%
df_1
# Out:
#          Customer Name         State   Sales   Profit
# 5663       Jason Gross          Ohio  18.656   1.3992
# 2805  Charles Crestani         Texas  47.516  -2.0364
# 1407     Karen Daniels      New York  75.480  19.6248
# 4062       Bryan Davis  Pennsylvania  39.992   7.4985

# %%
df_2
# Out:
#         Customer Name         State    Sales   Profit
# 8325   Frank Carlisle       Florida  158.376  13.8579
# 5875     Frank Merwin  Pennsylvania   11.736   1.0269
# 9479  Shahid Shariari      Illinois    3.828  -6.5076
# 5980     Rick Bensley      Oklahoma  161.960  45.3488

# %%
df_3
# Out:
#           Customer Name       State    Sales    Profit
# 1417         Stuart Van       Texas  151.200   32.1300
# 4383  Russell Applegate    Illinois  384.944 -126.4816
# 7377        Mike Caudle  Washington   92.520   24.9804
# 6281       Jamie Kunitz        Ohio   63.824    9.5736

# %%
df_cat1 = pd.concat([df_1,df_2,df_3], axis=0)
df_cat1
# Out:
#           Customer Name         State    Sales    Profit
# 5663        Jason Gross          Ohio   18.656    1.3992
# 2805   Charles Crestani         Texas   47.516   -2.0364
# 1407      Karen Daniels      New York   75.480   19.6248
# 4062        Bryan Davis  Pennsylvania   39.992    7.4985
# 8325     Frank Carlisle       Florida  158.376   13.8579
# 5875       Frank Merwin  Pennsylvania   11.736    1.0269
# 9479    Shahid Shariari      Illinois    3.828   -6.5076
# 5980       Rick Bensley      Oklahoma  161.960   45.3488
# 1417         Stuart Van         Texas  151.200   32.1300
# 4383  Russell Applegate      Illinois  384.944 -126.4816
# 7377        Mike Caudle    Washington   92.520   24.9804
# 6281       Jamie Kunitz          Ohio   63.824    9.5736

# %%
df_cat2 = pd.concat([df_1,df_2,df_3], axis=1)
df_cat2
# Out:
#          Customer Name         State   Sales   Profit    Customer Name  \
# 5663       Jason Gross          Ohio  18.656   1.3992              NaN
# 2805  Charles Crestani         Texas  47.516  -2.0364              NaN
# 1407     Karen Daniels      New York  75.480  19.6248              NaN
# 4062       Bryan Davis  Pennsylvania  39.992   7.4985              NaN
# 8325               NaN           NaN     NaN      NaN   Frank Carlisle
# 5875               NaN           NaN     NaN      NaN     Frank Merwin
# 9479               NaN           NaN     NaN      NaN  Shahid Shariari
# 5980               NaN           NaN     NaN      NaN     Rick Bensley
# 1417               NaN           NaN     NaN      NaN              NaN
# 4383               NaN           NaN     NaN      NaN              NaN
# 7377               NaN           NaN     NaN      NaN              NaN
# 6281               NaN           NaN     NaN      NaN              NaN
#
#              State    Sales   Profit      Customer Name       State    Sales  \
# 5663           NaN      NaN      NaN                NaN         NaN      NaN
# 2805           NaN      NaN      NaN                NaN         NaN      NaN
# 1407           NaN      NaN      NaN                NaN         NaN      NaN
# 4062           NaN      NaN      NaN                NaN         NaN      NaN
# 8325       Florida  158.376  13.8579                NaN         NaN      NaN
# 5875  Pennsylvania   11.736   1.0269                NaN         NaN      NaN
# 9479      Illinois    3.828  -6.5076                NaN         NaN      NaN
# 5980      Oklahoma  161.960  45.3488                NaN         NaN      NaN
# 1417           NaN      NaN      NaN         Stuart Van       Texas  151.200
# 4383           NaN      NaN      NaN  Russell Applegate    Illinois  384.944
# 7377           NaN      NaN      NaN        Mike Caudle  Washington   92.520
# 6281           NaN      NaN      NaN       Jamie Kunitz        Ohio   63.824
#
#         Profit
# 5663       NaN
# 2805       NaN
# 1407       NaN
# 4062       NaN
# 8325       NaN
# 5875       NaN
# 9479       NaN
# 5980       NaN
# 1417   32.1300
# 4383 -126.4816
# 7377   24.9804
# 6281    9.5736

# %% [markdown]
# ### Exercise 13: Merging by a common key

# %%
df_1=df[['Customer Name','Ship Date','Ship Mode']][0:4]
df_1
# Out:
#      Customer Name  Ship Date       Ship Mode
# 0      Claire Gute 2016-11-11    Second Class
# 1      Claire Gute 2016-11-11    Second Class
# 2  Darrin Van Huff 2016-06-16    Second Class
# 3   Sean O'Donnell 2015-10-18  Standard Class

# %%
df_2=df[['Customer Name','Product Name','Quantity']][0:4]
df_2
# Out:
#      Customer Name                                       Product Name  \
# 0      Claire Gute                  Bush Somerset Collection Bookcase
# 1      Claire Gute  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2  Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...
# 3   Sean O'Donnell      Bretford CR4500 Series Slim Rectangular Table
#
#    Quantity
# 0         2
# 1         3
# 2         2
# 3         5

# %%
pd.merge(df_1,df_2,on='Customer Name',how='inner')
# Out:
#      Customer Name  Ship Date       Ship Mode  \
# 0      Claire Gute 2016-11-11    Second Class
# 1      Claire Gute 2016-11-11    Second Class
# 2      Claire Gute 2016-11-11    Second Class
# 3      Claire Gute 2016-11-11    Second Class
# 4  Darrin Van Huff 2016-06-16    Second Class
# 5   Sean O'Donnell 2015-10-18  Standard Class
#
#                                         Product Name  Quantity
# 0                  Bush Somerset Collection Bookcase         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...         3
# 2                  Bush Somerset Collection Bookcase         2
# 3  Hon Deluxe Fabric Upholstered Stacking Chairs,...         3
# 4  Self-Adhesive Address Labels for Typewriters b...         2
# 5      Bretford CR4500 Series Slim Rectangular Table         5

# %%
pd.merge(df_1,df_2,on='Customer Name',how='inner').drop_duplicates()
# Out:
#      Customer Name  Ship Date       Ship Mode  \
# 0      Claire Gute 2016-11-11    Second Class
# 1      Claire Gute 2016-11-11    Second Class
# 4  Darrin Van Huff 2016-06-16    Second Class
# 5   Sean O'Donnell 2015-10-18  Standard Class
#
#                                         Product Name  Quantity
# 0                  Bush Somerset Collection Bookcase         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...         3
# 4  Self-Adhesive Address Labels for Typewriters b...         2
# 5      Bretford CR4500 Series Slim Rectangular Table         5

# %%
df_3=df[['Customer Name','Product Name','Quantity']][2:6]
df_3
# Out:
#      Customer Name                                       Product Name  \
# 2  Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...
# 3   Sean O'Donnell      Bretford CR4500 Series Slim Rectangular Table
# 4   Sean O'Donnell                     Eldon Fold 'N Roll Cart System
# 5  Brosina Hoffman  Eldon Expressions Wood and Plastic Desk Access...
#
#    Quantity
# 2         2
# 3         5
# 4         2
# 5         7

# %%
pd.merge(df_1,df_3,on='Customer Name',how='inner').drop_duplicates()
# Out:
#      Customer Name  Ship Date       Ship Mode  \
# 0  Darrin Van Huff 2016-06-16    Second Class
# 1   Sean O'Donnell 2015-10-18  Standard Class
# 2   Sean O'Donnell 2015-10-18  Standard Class
#
#                                         Product Name  Quantity
# 0  Self-Adhesive Address Labels for Typewriters b...         2
# 1      Bretford CR4500 Series Slim Rectangular Table         5
# 2                     Eldon Fold 'N Roll Cart System         2

# %%
pd.merge(df_1,df_3,on='Customer Name',how='outer').drop_duplicates()
# Out:
#      Customer Name  Ship Date       Ship Mode  \
# 0  Brosina Hoffman        NaT             NaN
# 1      Claire Gute 2016-11-11    Second Class
# 3  Darrin Van Huff 2016-06-16    Second Class
# 4   Sean O'Donnell 2015-10-18  Standard Class
# 5   Sean O'Donnell 2015-10-18  Standard Class
#
#                                         Product Name  Quantity
# 0  Eldon Expressions Wood and Plastic Desk Access...       7.0
# 1                                                NaN       NaN
# 3  Self-Adhesive Address Labels for Typewriters b...       2.0
# 4      Bretford CR4500 Series Slim Rectangular Table       5.0
# 5                     Eldon Fold 'N Roll Cart System       2.0

# %% [markdown]
# ### Exercise 14: Join method

# %%
df_1=df[['Customer Name','Ship Date','Ship Mode']][0:4]
df_1.set_index(['Customer Name'],inplace=True)
df_1
# Out:
#                  Ship Date       Ship Mode
# Customer Name
# Claire Gute     2016-11-11    Second Class
# Claire Gute     2016-11-11    Second Class
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class

# %%
df_2=df[['Customer Name','Product Name','Quantity']][2:6]
df_2.set_index(['Customer Name'],inplace=True)
df_2
# Out:
#                                                       Product Name  Quantity
# Customer Name
# Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...         2
# Sean O'Donnell       Bretford CR4500 Series Slim Rectangular Table         5
# Sean O'Donnell                      Eldon Fold 'N Roll Cart System         2
# Brosina Hoffman  Eldon Expressions Wood and Plastic Desk Access...         7

# %%
df_1.join(df_2,how='left').drop_duplicates()
# Out:
#                  Ship Date       Ship Mode  \
# Customer Name
# Claire Gute     2016-11-11    Second Class
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class
# Sean O'Donnell  2015-10-18  Standard Class
#
#                                                       Product Name  Quantity
# Customer Name
# Claire Gute                                                    NaN       NaN
# Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...       2.0
# Sean O'Donnell       Bretford CR4500 Series Slim Rectangular Table       5.0
# Sean O'Donnell                      Eldon Fold 'N Roll Cart System       2.0

# %%
df_1.join(df_2,how='right').drop_duplicates()
# Out:
#                  Ship Date       Ship Mode  \
# Customer Name
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class
# Sean O'Donnell  2015-10-18  Standard Class
# Brosina Hoffman        NaT             NaN
#
#                                                       Product Name  Quantity
# Customer Name
# Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...         2
# Sean O'Donnell       Bretford CR4500 Series Slim Rectangular Table         5
# Sean O'Donnell                      Eldon Fold 'N Roll Cart System         2
# Brosina Hoffman  Eldon Expressions Wood and Plastic Desk Access...         7

# %%
df_1.join(df_2,how='inner').drop_duplicates()
# Out:
#                  Ship Date       Ship Mode  \
# Customer Name
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class
# Sean O'Donnell  2015-10-18  Standard Class
#
#                                                       Product Name  Quantity
# Customer Name
# Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...         2
# Sean O'Donnell       Bretford CR4500 Series Slim Rectangular Table         5
# Sean O'Donnell                      Eldon Fold 'N Roll Cart System         2

# %%
df_1.join(df_2,how='outer').drop_duplicates()
# Out:
#                  Ship Date       Ship Mode  \
# Customer Name
# Brosina Hoffman        NaT             NaN
# Claire Gute     2016-11-11    Second Class
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class
# Sean O'Donnell  2015-10-18  Standard Class
#
#                                                       Product Name  Quantity
# Customer Name
# Brosina Hoffman  Eldon Expressions Wood and Plastic Desk Access...       7.0
# Claire Gute                                                    NaN       NaN
# Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...       2.0
# Sean O'Donnell       Bretford CR4500 Series Slim Rectangular Table       5.0
# Sean O'Donnell                      Eldon Fold 'N Roll Cart System       2.0

# %% [markdown]
# ## Miscelleneous useful methods

# %% [markdown]
# ### Exercise 15: Randomized sampling - `sample` method

# %%
df.sample(n=5)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2327  CA-2015-105102 2015-09-15 2015-09-19    Second Class    BM-11575
# 7853  CA-2015-144890 2015-12-25 2015-12-29  Standard Class    SM-20320
# 8422  CA-2017-150091 2017-10-12 2017-10-16  Standard Class    NP-18670
# 2821  CA-2017-100202 2016-12-31 2017-01-05  Standard Class    BD-11620
# 6571  CA-2014-100678 2014-04-18 2014-04-22  Standard Class    KM-16720
#
#         Customer Name      Segment           City       State  Postal Code  \
# 2327    Brendan Murry    Corporate  New York City    New York        10035
# 7853      Sean Miller  Home Office    Los Angeles  California        90049
# 8422       Nora Paige     Consumer       Lakewood  New Jersey         8701
# 2821  Brian DeCherney     Consumer        Anaheim  California        92804
# 6571     Kunst Miller     Consumer        Houston       Texas        77095
#
#        Region       Product ID         Category Sub-Category  \
# 2327     East  OFF-PA-10002365  Office Supplies        Paper
# 7853     West  OFF-PA-10001526  Office Supplies        Paper
# 8422     East  OFF-FA-10000621  Office Supplies    Fasteners
# 2821     West  TEC-PH-10002563       Technology       Phones
# 6571  Central  TEC-AC-10000474       Technology  Accessories
#
#                                            Product Name    Sales  Quantity  \
# 2327                                         Xerox 1967   12.960         2
# 7853                                         Xerox 1949    9.960         2
# 8422           OIC Colored Binder Clips, Assorted Sizes   17.900         5
# 2821                                   Adtran 1202752G1  302.376         3
# 6571  Kensington Expert Mouse Optical USB Trackball ...  227.976         3
#
#       Discount   Profit
# 2327       0.0   6.2208
# 7853       0.0   4.8804
# 8422       0.0   8.7710
# 2821       0.2  22.6782
# 6571       0.2  28.4970

# %%
df.sample(frac=0.001)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 6703  CA-2015-139164 2015-06-23 2015-06-28  Standard Class    CS-12355
# 3912  CA-2017-148068 2017-09-18 2017-09-25  Standard Class    MM-18280
# 2600  CA-2017-108553 2017-04-23 2017-04-29  Standard Class    SK-19990
# 8540  CA-2017-147354 2017-03-09 2017-03-13  Standard Class    KB-16315
# 9821  CA-2015-162201 2015-06-08 2015-06-12  Standard Class    AG-10495
# 281   US-2015-161991 2015-09-26 2015-09-28    Second Class    SC-20725
# 9561  CA-2016-129280 2016-05-03 2016-05-05     First Class    SM-20905
# 7344  CA-2017-168389 2017-12-11 2017-12-17  Standard Class    DV-13045
# 2719  CA-2014-110030 2014-12-06 2014-12-08    Second Class    LF-17185
# 6689  CA-2017-104108 2017-12-02 2017-12-09  Standard Class    RP-19855
#
#              Customer Name    Segment              City       State  \
# 6703  Christine Sundaresam   Consumer        Long Beach  California
# 3912    Muhammed MacIntyre  Corporate     New York City    New York
# 2600         Sally Knutson   Consumer     New York City    New York
# 8540            Karl Braun   Consumer       Los Angeles  California
# 9821       Andrew Gjertsen  Corporate  Saint Petersburg     Florida
# 281      Steven Cartwright   Consumer           Houston       Texas
# 9561     Susan MacKendrick   Consumer            Newark        Ohio
# 7344       Darrin Van Huff  Corporate      Jacksonville     Florida
# 2719           Luke Foster   Consumer           Houston       Texas
# 6689              Roy Phan  Corporate           Houston       Texas
#
#       Postal Code   Region       Product ID         Category Sub-Category  \
# 6703        90805     West  TEC-PH-10002468       Technology       Phones
# 3912        10035     East  OFF-PA-10001639  Office Supplies        Paper
# 2600        10024     East  OFF-SU-10002573  Office Supplies     Supplies
# 8540        90008     West  OFF-BI-10003910  Office Supplies      Binders
# 9821        33710    South  OFF-BI-10002429  Office Supplies      Binders
# 281         77070  Central  TEC-PH-10001760       Technology       Phones
# 9561        43055     East  TEC-AC-10002637       Technology  Accessories
# 7344        32216    South  FUR-TA-10004289        Furniture       Tables
# 2719        77095  Central  FUR-FU-10002759        Furniture  Furnishings
# 6689        77095  Central  OFF-AR-10000817  Office Supplies          Art
#
#                                            Product Name     Sales  Quantity  \
# 6703  Plantronics CS 50-USB - headset - Convertible,...   217.584         2
# 3912                                          Xerox 203    19.440         3
# 2600              Acme 10" Easy Grip Assistive Scissors   122.710         7
# 8540  DXL Angle-View Binders with Locking Rings by S...    30.840         5
# 9821              Premier Elliptical Ring Binder, Black    18.264         2
# 281                    Bose SoundLink Bluetooth Speaker  1114.400         7
# 9561  Logitech VX Revolution Cordless Laser Mouse fo...   431.976         3
# 7344  BoxOffice By Design Rectangular and Half-Moon ...   721.875         6
# 2719                   12-1/2 Diameter Round Wall Clock    23.976         3
# 6689             Manco Dry-Lighter Erasable Highlighter    12.160         5
#
#       Discount    Profit
# 6703      0.20   19.0386
# 3912      0.00    9.3312
# 2600      0.00   36.8130
# 8540      0.20    9.6375
# 9821      0.70  -13.3936
# 281       0.20  376.1100
# 9561      0.20  -75.5958
# 7344      0.45 -420.0000
# 2719      0.60  -14.3856
# 6689      0.20    2.1280

# %%
df.sample(frac=0.001,replace=True)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2809  CA-2015-148635 2015-07-25 2015-07-27    Second Class    MH-18025
# 2858  CA-2017-138975 2017-05-19 2017-05-23  Standard Class    SC-20380
# 1250  CA-2017-115602 2017-12-18 2017-12-24  Standard Class    DJ-13630
# 9695  US-2016-151260 2016-12-11 2016-12-14     First Class    SC-20695
# 5376  CA-2017-134152 2017-05-27 2017-05-31  Standard Class    RP-19855
# 8188  CA-2015-140375 2015-10-02 2015-10-05    Second Class    SG-20470
# 8396  CA-2014-152254 2014-06-30 2014-06-30        Same Day    BD-11620
# 9067  CA-2016-150077 2016-02-04 2016-02-10  Standard Class    MS-17365
# 6881  CA-2015-137113 2015-12-01 2015-12-05    Second Class    TW-21025
# 5792  CA-2017-140186 2017-09-29 2017-10-02     First Class    PG-18820
#
#             Customer Name      Segment           City           State  \
# 2809   Michelle Huthwaite     Consumer        Seattle      Washington
# 2858     Shahid Collister     Consumer        Atlanta         Georgia
# 1250          Doug Jacobs     Consumer  New York City        New York
# 9695        Steve Chapman    Corporate    Springfield            Ohio
# 5376             Roy Phan    Corporate        Seattle      Washington
# 8188         Sheri Gordon     Consumer      Rockville        Maryland
# 8396      Brian DeCherney     Consumer     Wilmington  North Carolina
# 9067  Maribeth Schnelling     Consumer      Rockville        Maryland
# 6881    Tamara Willingham  Home Office        Seattle      Washington
# 5792      Patrick Gardner     Consumer    Bakersfield      California
#
#       Postal Code Region       Product ID         Category Sub-Category  \
# 2809        98115   West  FUR-CH-10001854        Furniture       Chairs
# 2858        30318  South  TEC-AC-10003441       Technology  Accessories
# 1250        10009   East  OFF-AP-10000891  Office Supplies   Appliances
# 9695        45503   East  OFF-AP-10002892  Office Supplies   Appliances
# 5376        98103   West  OFF-AR-10004062  Office Supplies          Art
# 8188        20852   East  OFF-PA-10001870  Office Supplies        Paper
# 8396        28403  South  OFF-PA-10001144  Office Supplies        Paper
# 9067        20852   East  TEC-PH-10002890       Technology       Phones
# 6881        98105   West  FUR-TA-10001705        Furniture       Tables
# 5792        93309   West  OFF-AP-10002578  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 2809  Office Star - Professional Matrix Back Chair w...   561.568         2
# 2858         Kingston Digital DataTraveler 32GB USB 2.0    67.800         4
# 1250  Kensington 7 Outlet MasterPiece HOMEOFFICE Pow...  1704.560        13
# 9695                   Belkin F5C206VTEL 6 Outlet Surge    73.536         4
# 5376                            Staples in misc. colors    31.440         3
# 8188                                          Xerox 202    19.440         3
# 8396                                         Xerox 1913   310.688         7
# 9067                      AT&T 17929 Lendline Telephone    90.480         2
# 6881   Bush Advantage Collection Round Conference Table  1913.400         9
# 5792  Fellowes Premier Superior Surge Suppressor, 10...    97.840         2
#
#       Discount    Profit
# 2809       0.2   28.0784
# 2858       0.0    4.0680
# 1250       0.0  511.3680
# 9695       0.2    9.1920
# 5376       0.0    7.8600
# 8188       0.0    9.3312
# 8396       0.2  108.7408
# 9067       0.0   23.5248
# 6881       0.0  401.8140
# 5792       0.0   25.4384

# %% [markdown]
# ### Exercise 16: Pandas `value_count` method to return unique records

# %%
df['Customer Name'].value_counts()[:10]
# Out:
# Customer Name
# William Brown          37
# Matt Abelman           34
# John Lee               34
# Paul Prost             34
# Chloris Kastensmidt    32
# Jonathan Doherty       32
# Edward Hooks           32
# Seth Vernon            32
# Zuschuss Carroll       31
# Emily Phan             31
# Name: count, dtype: int64

# %% [markdown]
# ### Exercise 17: Pivot table functionality - `pivot_table`

# %%
df_sample=df.sample(n=100)

# %%
df_sample.pivot_table(values=['Sales','Quantity','Profit'],index=['Region','State'],aggfunc='mean')

# %% [markdown]
# ### Exercise 18: Sorting by particular column

# %%
df_sample=df[['Customer Name','State','Sales','Quantity']].sample(n=15)
df_sample

# %%
df_sample.sort_values(by='Sales')

# %%
df_sample.sort_values(by=['State','Sales'])

# %% [markdown]
# ### Exercise 19: Flexibility for user-defined function with `apply` method

# %%
def categorize_sales(price):
    if price < 50:
        return "Low"
    elif price < 200:
        return "Medium"
    else:
        return "High"

# %%
df_sample=df[['Customer Name','State','Sales']].sample(n=100)
df_sample.head(10)

# %%
df_sample['Sales Price Category']=df_sample['Sales'].apply(categorize_sales)
df_sample.head(10)

# %%
df_sample['Customer Name Length']=df_sample['Customer Name'].apply(len)
df_sample.head(10)

# %%
df_sample['Discounted Price']=df_sample['Sales'].apply(lambda x:0.85*x if x>200 else x)
df_sample.head(10)
